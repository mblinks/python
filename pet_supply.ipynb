# %% [markdown]
# ## Task 1

# %% [markdown]
# *The table contains 1500 rows and 8 columns, with missing values before cleaning. I have validated all the columns against the criteria in the dataset table:*
#
# product_id: Same as description without missing values
#
# category: the column contain 6 unique categories in addition to 25 rows with "-" which was replaced with "Unknown"
#
# animal: Same as description without missing values, 4 types of animal
#
# size: there are Small, Medium and Large size, however the capitalization is not uniform for some rows. I transformed the column so that the first alphabet is Capital while the others are small as found in "Small", "Medium" and "Large"
#
# price: the column contains 150 "unlisted" prices. I transformed the column by removing all unlisted and replacing with the overall median price and subsequently into 2 decimal places
#
# sales: Same as description without missing values
#
# rating: the column contains 150 missing values, I replaced the missing value with 0
#
# repeat_purchase: Same as description without missing values*

# %% [markdown]
# ## Task 2

# %% [markdown]
# _Out of 1500 products, 906 are repeat purchase representing 60.4% of the total products while 594 are not repeat purchase (39.6%)_
#
# ![Repeat purchase of product](Task 2_i.png)
#
# The category of product with the most repeat purchase is "equipment" with a total of 221 repeat purchases. The food, housing and medical categories have a comparable number of repeat purchases (151, 152, and 153 respectively). This was closely followed by the Toy category where 145 repeat purchases were recorded. Accesory accounted for 70 repeat purchases while the category named "Unknown" was the least in terms of repeat purchases (14).
#
# The observations are not balanced across categories of repeat purchases. Only four of the categories (food, housing, medicine and toys) are approcimately equal in terms of repeat purchases with approximately 16-17% repeat purchase. The repeat purchase is spread in different proportion across other categories.
#
# ![Comparison of repeat purchases across categories](Task 2.png)

# %% [markdown]
# ## Task 3

# %% [markdown]
# Products with values between 875 and 1063 had the highest count of over 400. Products with sale value of about 750 were sold over 300 times. Sales with within a value range of 500 - 700 and 1060 - 1025 had approximately equal number of patronage accounting for about 180 counts. Sales above 1800 accounted for the least number of occurence throughout the year under study. In all, the sales are symmetrically distributed.
#
# ![Sales distribution](Task 3.png)

# %% [markdown]
# ## Task 4

# %% [markdown]
# ![Comparison of sales with repeat purchases](Task 4_i.png)
# _The graph shows the number of sales for repeat and non repeat product. There is a slightly higher median sales for non repeat purchase products compared to the repeat purchase products_
# The repeat purchase product has less spread in terms of sales compared to non-repeat purchase. However, there are several higher sales for repeat purchase products compared to the non repeat purchase product.
#
# The violin plot comparing the sales of each category with repeat purchase shows that food has median repeat purchase sales above 1000 with fewer sales above 2000. More repeat purchase sales for medicine were made between 500 and 1000 compared to other sales for that category. Repeat purchase sales for the housing category are highly concentrated around the median sales value. The accessory category has a low density repeat purchase sales distribution with no outliers. Equipment category have two modes of repeat purchase sales with higher sales density above 1000. The toy category has the highest median repeat purchase value across all categories, it also recorded the highest sales outlier compared to others. The unknown category exhibited a normal distribution of repeat purchase sales with outliers at both ends. In all the relationship between sales and repeat purchase varied across groups.
#
# ![Variation of repeat purchase sales across categories](Task 4.png)

# %% [markdown]
# ## ✅ When you have finished...
# -  Publish your Workspace using the option on the left
# -  Check the published version of your report:
# 	-  Can you see everything you want us to grade?
#     -  Are all the graphics visible?
# -  Review the grading rubric. Have you included everything that will be graded?
# -  Head back to the [Certification Dashboard](https://app.datacamp.com/certification) to submit your practical exam
